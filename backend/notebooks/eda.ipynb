# %%
top_effects = data["SideEffect_Name"].value_counts().head(20)

plt.figure(figsize=(12,8))

sns.barplot(
    x=top_effects.values,
    y=top_effects.index,
    hue=top_effects.index,
    legend=False,
    palette="magma"
)

plt.title("Top 20 Most Common Side Effects")
plt.xlabel("Occurrences")
plt.ylabel("Side Effect")

plt.tight_layout()
plt.show()

# %%
top_drugs = data["Drug_Name"].value_counts().head(20)

plt.figure(figsize=(12,8))

sns.barplot(
    x=top_drugs.values,
    y=top_drugs.index,
    hue=top_drugs.index,
    legend=False,
    palette="viridis"
)

plt.title("Top 20 Drugs with the Highest Number of Reported Side Effects")
plt.xlabel("Number of Side Effects")
plt.ylabel("Drug Name")

plt.tight_layout()
plt.show()

# %%
data.describe(include="all")
# Out:
#              Drug_ID       UMLS_ID MedDRA_Concept_ID Term_Type SideEffect_ID  \
# count         308948        308948            308948    308948        308948
# unique          1430          1556              5805         2          6060
# top     CID100002771  CID000060795          C0015230        PT      C0012833
# freq            2181          1608              3459    163206          2826
#
#        SideEffect_Name   Drug_Name
# count           308948      308948
# unique            6060        1347
# top          Dizziness  citalopram
# freq              2826        2181

# %%
data.isnull().sum()
# Out:
# Drug_ID              0
# UMLS_ID              0
# MedDRA_Concept_ID    0
# Term_Type            0
# SideEffect_ID        0
# SideEffect_Name      0
# Drug_Name            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 308948 entries, 0 to 308947
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Drug_ID            308948 non-null  str
#  1   UMLS_ID            308948 non-null  str
#  2   MedDRA_Concept_ID  308948 non-null  str
#  3   Term_Type          308948 non-null  str
#  4   SideEffect_ID      308948 non-null  str
#  5   SideEffect_Name    308948 non-null  str
#  6   Drug_Name          308948 non-null  str
# dtypes: str(7)
# memory usage: 16.5 MB

# %%
from pathlib import Path

BASE_DIR = Path.cwd().parent

data = pd.read_csv(
    BASE_DIR / "datasets" / "processed" / "cleaned_side_effects.csv"
)

print(data.shape)
data.head()
# Out:
# (308948, 7)
#         Drug_ID       UMLS_ID MedDRA_Concept_ID Term_Type SideEffect_ID  \
# 0  CID100000085  CID000010917          C0000729       LLT      C0000729
# 1  CID100000085  CID000010917          C0000729        PT      C0000737
# 2  CID100000085  CID000010917          C0000737       LLT      C0000737
# 3  CID100000085  CID000010917          C0000737        PT      C0687713
# 4  CID100000085  CID000010917          C0000737        PT      C0000737
#
#          SideEffect_Name  Drug_Name
# 0       Abdominal cramps  carnitine
# 1         Abdominal pain  carnitine
# 2         Abdominal pain  carnitine
# 3  Gastrointestinal pain  carnitine
# 4         Abdominal pain  carnitine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Make graphs look better
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (12,6)
# Out:
# Matplotlib is building the font cache; this may take a moment.
